# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
from currency_symbols import CurrencySymbols as cs

# %%
data = pd.read_csv("Cheapestelectriccars-EVDatabase.csv")

# %%
data
# Out:
#                                     Name  \
# 0                         Opel Ampera-e
# 1              Renault Kangoo Maxi ZE 33
# 2                           Nissan Leaf
# 3       Audi e-tron Sportback 55 quattro
# 4                 Porsche Taycan Turbo S
# ..                                   ...
# 175                         MG Marvel R
# 176  Tesla Model 3 Long Range Dual Motor
# 177                 MG MG5 EV Long Range
# 178            Audi Q4 e-tron 45 quattro
# 179          Audi Q4 Sportback e-tron 40
#
#                                       Subtitle Acceleration  TopSpeed   Range  \
# 0     Battery Electric Vehicle |       58 kWh       7.3 sec  150 km/h  335 km
# 1     Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h  160 km
# 2     Battery Electric Vehicle |       36 kWh       7.9 sec  144 km/h  220 km
# 3    Battery Electric Vehicle |       86.5 kWh      5.7 sec  200 km/h  375 km
# ...

# %%
data['PriceinUK'] =  data.PriceinUK.str.replace(cs.get_symbol('GBP'),"")

# %%
data
# Out:
#                                     Name  \
# 0                         Opel Ampera-e
# 1              Renault Kangoo Maxi ZE 33
# 2                           Nissan Leaf
# 3       Audi e-tron Sportback 55 quattro
# 4                 Porsche Taycan Turbo S
# ..                                   ...
# 175                         MG Marvel R
# 176  Tesla Model 3 Long Range Dual Motor
# 177                 MG MG5 EV Long Range
# 178            Audi Q4 e-tron 45 quattro
# 179          Audi Q4 Sportback e-tron 40
#
#                                       Subtitle Acceleration  TopSpeed   Range  \
# 0     Battery Electric Vehicle |       58 kWh       7.3 sec  150 km/h  335 km
# 1     Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h  160 km
# 2     Battery Electric Vehicle |       36 kWh       7.9 sec  144 km/h  220 km
# 3    Battery Electric Vehicle |       86.5 kWh      5.7 sec  200 km/h  375 km
# ...

# %%
data['PriceinGermany'] =  data.PriceinGermany.str.replace(cs.get_symbol('EUR'),"")

# %%
data
# Out:
#                                     Name  \
# 0                         Opel Ampera-e
# 1              Renault Kangoo Maxi ZE 33
# 2                           Nissan Leaf
# 3       Audi e-tron Sportback 55 quattro
# 4                 Porsche Taycan Turbo S
# ..                                   ...
# 175                         MG Marvel R
# 176  Tesla Model 3 Long Range Dual Motor
# 177                 MG MG5 EV Long Range
# 178            Audi Q4 e-tron 45 quattro
# 179          Audi Q4 Sportback e-tron 40
#
#                                       Subtitle Acceleration  TopSpeed   Range  \
# 0     Battery Electric Vehicle |       58 kWh       7.3 sec  150 km/h  335 km
# 1     Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h  160 km
# 2     Battery Electric Vehicle |       36 kWh       7.9 sec  144 km/h  220 km
# 3    Battery Electric Vehicle |       86.5 kWh      5.7 sec  200 km/h  375 km
# ...

# %%
data = data.replace(np.nan,0)

# %%
data
# Out:
#                                     Name  \
# 0                         Opel Ampera-e
# 1              Renault Kangoo Maxi ZE 33
# 2                           Nissan Leaf
# 3       Audi e-tron Sportback 55 quattro
# 4                 Porsche Taycan Turbo S
# ..                                   ...
# 175                         MG Marvel R
# 176  Tesla Model 3 Long Range Dual Motor
# 177                 MG MG5 EV Long Range
# 178            Audi Q4 e-tron 45 quattro
# 179          Audi Q4 Sportback e-tron 40
#
#                                       Subtitle Acceleration  TopSpeed   Range  \
# 0     Battery Electric Vehicle |       58 kWh       7.3 sec  150 km/h  335 km
# 1     Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h  160 km
# 2     Battery Electric Vehicle |       36 kWh       7.9 sec  144 km/h  220 km
# 3    Battery Electric Vehicle |       86.5 kWh      5.7 sec  200 km/h  375 km
# ...

# %%
data['PriceinUK']= data.PriceinUK.str.replace(',',"")

# %%
data['PriceinGermany']= data.PriceinGermany.str.replace(',',"")

# %%
data
# Out:
#                                     Name  \
# 0                         Opel Ampera-e
# 1              Renault Kangoo Maxi ZE 33
# 2                           Nissan Leaf
# 3       Audi e-tron Sportback 55 quattro
# 4                 Porsche Taycan Turbo S
# ..                                   ...
# 175                         MG Marvel R
# 176  Tesla Model 3 Long Range Dual Motor
# 177                 MG MG5 EV Long Range
# 178            Audi Q4 e-tron 45 quattro
# 179          Audi Q4 Sportback e-tron 40
#
#                                       Subtitle Acceleration  TopSpeed   Range  \
# 0     Battery Electric Vehicle |       58 kWh       7.3 sec  150 km/h  335 km
# 1     Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h  160 km
# 2     Battery Electric Vehicle |       36 kWh       7.9 sec  144 km/h  220 km
# 3    Battery Electric Vehicle |       86.5 kWh      5.7 sec  200 km/h  375 km
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Subtitle', 'Acceleration', 'TopSpeed', 'Range', 'Efficiency',
#        'FastChargeSpeed', 'Drive', 'NumberofSeats', 'PriceinGermany',
#        'PriceinUK'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Name               object
# Subtitle           object
# Acceleration       object
# TopSpeed           object
# Range              object
# Efficiency         object
# FastChargeSpeed    object
# Drive              object
# NumberofSeats       int64
# PriceinGermany     object
# PriceinUK          object
# dtype: object

# %%
data['Manufacturer'] = data.Name.str.split(" ",n = 1, expand = True)[0]

# %%
data
# Out:
#                                     Name  \
# 0                         Opel Ampera-e
# 1              Renault Kangoo Maxi ZE 33
# 2                           Nissan Leaf
# 3       Audi e-tron Sportback 55 quattro
# 4                 Porsche Taycan Turbo S
# ..                                   ...
# 175                         MG Marvel R
# 176  Tesla Model 3 Long Range Dual Motor
# 177                 MG MG5 EV Long Range
# 178            Audi Q4 e-tron 45 quattro
# 179          Audi Q4 Sportback e-tron 40
#
#                                       Subtitle Acceleration  TopSpeed   Range  \
# 0     Battery Electric Vehicle |       58 kWh       7.3 sec  150 km/h  335 km
# 1     Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h  160 km
# 2     Battery Electric Vehicle |       36 kWh       7.9 sec  144 km/h  220 km
# 3    Battery Electric Vehicle |       86.5 kWh      5.7 sec  200 km/h  375 km
# ...

# %%
data['FastChargeSpeed_wtihout_KMperHour'] = data.FastChargeSpeed.str.split(" ",n = 1, expand = True)[0]

# %%
data
# Out:
#                                     Name  \
# 0                         Opel Ampera-e
# 1              Renault Kangoo Maxi ZE 33
# 2                           Nissan Leaf
# 3       Audi e-tron Sportback 55 quattro
# 4                 Porsche Taycan Turbo S
# ..                                   ...
# 175                         MG Marvel R
# 176  Tesla Model 3 Long Range Dual Motor
# 177                 MG MG5 EV Long Range
# 178            Audi Q4 e-tron 45 quattro
# 179          Audi Q4 Sportback e-tron 40
#
#                                       Subtitle Acceleration  TopSpeed   Range  \
# 0     Battery Electric Vehicle |       58 kWh       7.3 sec  150 km/h  335 km
# 1     Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h  160 km
# 2     Battery Electric Vehicle |       36 kWh       7.9 sec  144 km/h  220 km
# 3    Battery Electric Vehicle |       86.5 kWh      5.7 sec  200 km/h  375 km
# ...

# %%
data['Efficiency_wtihout_Whperkm'] = data.Efficiency.str.split(" ",n = 1, expand = True)[0]

# %%
data['Range_wtihout_km'] = data.Range.str.split(" ",n = 1, expand = True)[0]

# %%
data['TopSpeed_wtihout_kmperhour'] = data.TopSpeed.str.split(" ",n = 1, expand = True)[0]

# %%
data['Acceleration_wtihout_sec'] = data.Acceleration.str.split(" ",n = 1, expand = True)[0]

# %%
data
# Out:
#                                     Name  \
# 0                         Opel Ampera-e
# 1              Renault Kangoo Maxi ZE 33
# 2                           Nissan Leaf
# 3       Audi e-tron Sportback 55 quattro
# 4                 Porsche Taycan Turbo S
# ..                                   ...
# 175                         MG Marvel R
# 176  Tesla Model 3 Long Range Dual Motor
# 177                 MG MG5 EV Long Range
# 178            Audi Q4 e-tron 45 quattro
# 179          Audi Q4 Sportback e-tron 40
#
#                                       Subtitle Acceleration  TopSpeed   Range  \
# 0     Battery Electric Vehicle |       58 kWh       7.3 sec  150 km/h  335 km
# 1     Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h  160 km
# 2     Battery Electric Vehicle |       36 kWh       7.9 sec  144 km/h  220 km
# 3    Battery Electric Vehicle |       86.5 kWh      5.7 sec  200 km/h  375 km
# ...

# %%
data['KWH'] = data.Subtitle.str.split("|",n = 1, expand = True)[1]

# %%
data
# Out:
#                                     Name  \
# 0                         Opel Ampera-e
# 1              Renault Kangoo Maxi ZE 33
# 2                           Nissan Leaf
# 3       Audi e-tron Sportback 55 quattro
# 4                 Porsche Taycan Turbo S
# ..                                   ...
# 175                         MG Marvel R
# 176  Tesla Model 3 Long Range Dual Motor
# 177                 MG MG5 EV Long Range
# 178            Audi Q4 e-tron 45 quattro
# 179          Audi Q4 Sportback e-tron 40
#
#                                       Subtitle Acceleration  TopSpeed   Range  \
# 0     Battery Electric Vehicle |       58 kWh       7.3 sec  150 km/h  335 km
# 1     Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h  160 km
# 2     Battery Electric Vehicle |       36 kWh       7.9 sec  144 km/h  220 km
# 3    Battery Electric Vehicle |       86.5 kWh      5.7 sec  200 km/h  375 km
# ...

# %%
data['KWH_without_kwh'] = data.KWH.str.split("kWh",n = 1, expand = True)[0]

# %%
data
# Out:
#                                     Name  \
# 0                         Opel Ampera-e
# 1              Renault Kangoo Maxi ZE 33
# 2                           Nissan Leaf
# 3       Audi e-tron Sportback 55 quattro
# 4                 Porsche Taycan Turbo S
# ..                                   ...
# 175                         MG Marvel R
# 176  Tesla Model 3 Long Range Dual Motor
# 177                 MG MG5 EV Long Range
# 178            Audi Q4 e-tron 45 quattro
# 179          Audi Q4 Sportback e-tron 40
#
#                                       Subtitle Acceleration  TopSpeed   Range  \
# 0     Battery Electric Vehicle |       58 kWh       7.3 sec  150 km/h  335 km
# 1     Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h  160 km
# 2     Battery Electric Vehicle |       36 kWh       7.9 sec  144 km/h  220 km
# 3    Battery Electric Vehicle |       86.5 kWh      5.7 sec  200 km/h  375 km
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Name                               180 non-null    object
#  1   Subtitle                           180 non-null    object
#  2   Acceleration                       180 non-null    object
#  3   TopSpeed                           180 non-null    object
#  4   Range                              180 non-null    object
#  5   Efficiency                         180 non-null    object
#  6   FastChargeSpeed                    180 non-null    object
#  7   Drive                              180 non-null    object
#  8   NumberofSeats                      180 non-null    int64
#  9   PriceinGermany                     168 non-null    object
#  10  PriceinUK                          136 non-null    object
# ...

# %%
data.head()
# Out:
#                                Name  \
# 0                    Opel Ampera-e
# 1         Renault Kangoo Maxi ZE 33
# 2                      Nissan Leaf
# 3  Audi e-tron Sportback 55 quattro
# 4            Porsche Taycan Turbo S
#
#                                     Subtitle Acceleration  TopSpeed   Range  \
# 0   Battery Electric Vehicle |       58 kWh       7.3 sec  150 km/h  335 km
# 1   Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h  160 km
# 2   Battery Electric Vehicle |       36 kWh       7.9 sec  144 km/h  220 km
# 3  Battery Electric Vehicle |       86.5 kWh      5.7 sec  200 km/h  375 km
# 4  Battery Electric Vehicle |       83.7 kWh      2.8 sec  260 km/h  390 km
#
#   Efficiency FastChargeSpeed              Drive  NumberofSeats PriceinGermany  \
# 0  173 Wh/km        210 km/h  Front Wheel Drive              5          42990
# 1  194 Wh/km               -  Front Wheel Drive              5            NaN
# ...

# %%
data['PriceinUK'] = pd.to_numeric(data['PriceinUK'])

# %%
data['PriceinGermany'] = pd.to_numeric(data['PriceinGermany'])

# %%
data['KWH_without_kwh']=pd.to_numeric(data['KWH_without_kwh'])

# %%
data['Acceleration_wtihout_sec']= pd.to_numeric(data['Acceleration_wtihout_sec'])

# %%
data['TopSpeed_wtihout_kmperhour'] = pd.to_numeric(data['TopSpeed_wtihout_kmperhour'])

# %%
data['Range_wtihout_km'] = pd.to_numeric(data['Range_wtihout_km'])

# %%
data['Efficiency_wtihout_Whperkm'] = pd.to_numeric(data['Efficiency_wtihout_Whperkm'])

# %%
data['FastChargeSpeed_wtihout_KMperHour'] = data.FastChargeSpeed_wtihout_KMperHour.replace('-',0)

# %%
data['FastChargeSpeed_wtihout_KMperHour'] = pd.to_numeric(data['FastChargeSpeed_wtihout_KMperHour'])

# %%
data.head()
# Out:
#                                Name  \
# 0                    Opel Ampera-e
# 1         Renault Kangoo Maxi ZE 33
# 2                      Nissan Leaf
# 3  Audi e-tron Sportback 55 quattro
# 4            Porsche Taycan Turbo S
#
#                                     Subtitle Acceleration  TopSpeed   Range  \
# 0   Battery Electric Vehicle |       58 kWh       7.3 sec  150 km/h  335 km
# 1   Battery Electric Vehicle |       31 kWh      22.4 sec  130 km/h  160 km
# 2   Battery Electric Vehicle |       36 kWh       7.9 sec  144 km/h  220 km
# 3  Battery Electric Vehicle |       86.5 kWh      5.7 sec  200 km/h  375 km
# 4  Battery Electric Vehicle |       83.7 kWh      2.8 sec  260 km/h  390 km
#
#   Efficiency FastChargeSpeed              Drive  NumberofSeats  \
# 0  173 Wh/km        210 km/h  Front Wheel Drive              5
# 1  194 Wh/km               -  Front Wheel Drive              5
# 2  164 Wh/km        230 km/h  Front Wheel Drive              5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Name                               180 non-null    object
#  1   Subtitle                           180 non-null    object
#  2   Acceleration                       180 non-null    object
#  3   TopSpeed                           180 non-null    object
#  4   Range                              180 non-null    object
#  5   Efficiency                         180 non-null    object
#  6   FastChargeSpeed                    180 non-null    object
#  7   Drive                              180 non-null    object
#  8   NumberofSeats                      180 non-null    int64
#  9   PriceinGermany                     168 non-null    float64
#  10  PriceinUK                          136 non-null    float64
# ...

# %%
data.corr(numeric_only = True)
# Out:
#                                    NumberofSeats  PriceinGermany  PriceinUK  \
# NumberofSeats                           1.000000       -0.046018  -0.059764
# PriceinGermany                         -0.046018        1.000000   0.984674
# PriceinUK                              -0.059764        0.984674   1.000000
# FastChargeSpeed_wtihout_KMperHour      -0.119644        0.621346   0.663077
# Efficiency_wtihout_Whperkm              0.602469        0.243519   0.337550
# Range_wtihout_km                       -0.068851        0.624719   0.686669
# TopSpeed_wtihout_kmperhour             -0.242567        0.753330   0.857726
# Acceleration_wtihout_sec                0.318302       -0.555890  -0.664348
# KWH_without_kwh                         0.134447        0.653291   0.717208
#
#                                    FastChargeSpeed_wtihout_KMperHour  \
# NumberofSeats                                              -0.119644
# ...

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(numeric_only = True) , annot = True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# The lighter the colour, the more the correlation between the two data points. we can see that price in Germany and price in the UK have a correlation of “0.7”, which is a good score. So, the correlation data has many real-life similarities.
# Top Speed has a high correlation to price in Germany and price in the UK. So, it makes sense. A car that has a higher top speed will have a higher price.  Similarly, vehicle range and KWH has a high correlation of 0.89, it is obvious as the battery capacity, more will be the range of the vehicle.

# %%
sns.countplot(x = 'Drive', data = data)
# Out:
# <AxesSubplot: xlabel='Drive', ylabel='count'>

# %%
sns.countplot(x = 'NumberofSeats', data = data)
# Out:
# <AxesSubplot: xlabel='NumberofSeats', ylabel='count'>

# %%
plt.figure(figsize = (8,6))
sns.countplot(x = 'NumberofSeats',hue = 'Drive', data = data)
# Out:
# <AxesSubplot: xlabel='NumberofSeats', ylabel='count'>

# %%
plt.figure(figsize=(18,10))
sns.countplot(y = 'Manufacturer',data = data)
# Out:
# <AxesSubplot: xlabel='count', ylabel='Manufacturer'>

# %% [markdown]
# We can see that Audi and Tesla have the most types of electric vehicles.

# %%
sns.relplot(x = 'KWH_without_kwh', y = 'Acceleration_wtihout_sec', hue = 'Drive', data = data)

# %%
sns.relplot(x = 'KWH_without_kwh', y = 'Acceleration_wtihout_sec', size = 'NumberofSeats',height = 6,sizes = (15,100), data = data)

# %%
sns.relplot(x = 'TopSpeed_wtihout_kmperhour', y = 'Range_wtihout_km', hue = 'Drive',height = 6, data = data)

# %%
sns.jointplot(x = 'KWH_without_kwh', y ='Range_wtihout_km',kind = 'hex', data = data)

# %%
sns.jointplot(x = 'KWH_without_kwh', y ='Efficiency_wtihout_Whperkm',kind = 'hex', data = data)

# %%
sns.relplot(x='FastChargeSpeed_wtihout_KMperHour', y='Efficiency_wtihout_Whperkm', data= data, height = 6)

# %%
data_prepocessing = data[['Name','Drive','Manufacturer','KWH','NumberofSeats','KWH_without_kwh','Acceleration_wtihout_sec','TopSpeed_wtihout_kmperhour','Range_wtihout_km','Efficiency_wtihout_Whperkm','FastChargeSpeed_wtihout_KMperHour','PriceinGermany','PriceinUK']]

# %%
data_prepocessing = data_prepocessing.replace(np.nan,0)

# %%
data_prepocessing
# Out:
#                                     Name              Drive Manufacturer  \
# 0                         Opel Ampera-e   Front Wheel Drive         Opel
# 1              Renault Kangoo Maxi ZE 33  Front Wheel Drive      Renault
# 2                           Nissan Leaf   Front Wheel Drive       Nissan
# 3       Audi e-tron Sportback 55 quattro    All Wheel Drive         Audi
# 4                 Porsche Taycan Turbo S    All Wheel Drive      Porsche
# ..                                   ...                ...          ...
# 175                         MG Marvel R    Rear Wheel Drive           MG
# 176  Tesla Model 3 Long Range Dual Motor    All Wheel Drive        Tesla
# 177                 MG MG5 EV Long Range  Front Wheel Drive           MG
# 178            Audi Q4 e-tron 45 quattro    All Wheel Drive         Audi
# 179          Audi Q4 Sportback e-tron 40   Rear Wheel Drive         Audi
#
#                  KWH  NumberofSeats  KWH_without_kwh  \
# ...

# %%
for i in range(0, len(data_prepocessing["PriceinUK"])):
    if (data_prepocessing["PriceinUK"][i]==0):
        val=data_prepocessing["PriceinGermany"][i]*0.85
        data_prepocessing["PriceinUK"][i]=val
# Out:
# C:\Users\AJ\AppData\Local\Temp\ipykernel_12960\6490141.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_prepocessing["PriceinUK"][i]=val

# %%
import category_encoders as ce

# %%
train_df = data_prepocessing

# %% [markdown]
# create object of Ordinalencoding

# %%
encoder = ce.OrdinalEncoder(cols=['Drive'],return_df=True,
                           mapping=[{'col':'Drive',
'mapping':{'Front Wheel Drive':1,'Rear Wheel Drive':2,'All Wheel Drive':3}}])

# %% [markdown]
# fit and transform train data

# %%
df_train = encoder.fit_transform(train_df) #Original data

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Name                               180 non-null    object
#  1   Drive                              180 non-null    int32
#  2   Manufacturer                       180 non-null    object
#  3   KWH                                180 non-null    object
#  4   NumberofSeats                      180 non-null    int64
#  5   KWH_without_kwh                    180 non-null    float64
#  6   Acceleration_wtihout_sec           180 non-null    float64
#  7   TopSpeed_wtihout_kmperhour         180 non-null    int64
#  8   Range_wtihout_km                   180 non-null    int64
#  9   Efficiency_wtihout_Whperkm         180 non-null    int64
#  10  FastChargeSpeed_wtihout_KMperHour  180 non-null    int64
# ...

# %%
X= df_train.drop(['Name', 'PriceinGermany','PriceinUK','Manufacturer','KWH'], axis=1)
X=X.values

# %%
X
# Out:
# array([[  1. ,   5. ,  58. , ..., 335. , 173. , 210. ],
#        [  1. ,   5. ,  31. , ..., 160. , 194. ,   0. ],
#        [  1. ,   5. ,  36. , ..., 220. , 164. , 230. ],
#        ...,
#        [  1. ,   5. ,  57. , ..., 340. , 168. , 340. ],
#        [  3. ,   5. ,  76.6, ..., 385. , 199. , 470. ],
#        [  2. ,   5. ,  76.6, ..., 425. , 180. , 520. ]])

# %%
y=df_train['PriceinUK'].values

# %%
X.shape
# Out:
# (180, 8)

# %%
y.shape
# Out:
# (180,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=7)

# %%
from sklearn.ensemble import RandomForestRegressor
# create regressor object
regressor = RandomForestRegressor(n_estimators = 300, random_state = 0)

# %%
# fit the regressor with x and y data
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=300, random_state=0)

# %%
y_pred= regressor.predict(X_test)

# %%
y_test
# Out:
# array([ 69905.  ,  30730.  ,  42000.  ,  38845.  , 110980.  ,  32550.  ,
#         43248.  ,  28420.  ,  48000.  ,  45145.  ,  28500.  ,  48824.  ,
#         49750.5 ,      0.  ,  57500.  ,  51531.25,  49465.  ,  45507.3 ,
#         41330.  ,  25491.5 ,  45000.  ,  88700.  ,  74739.  ,  59990.  ,
#         21675.  ,  55577.25,  29740.  ,  43265.  ,  32150.  ,  87820.  ,
#             0.  ,  54000.  ,  30500.  ,  90980.  ,  20495.  ,  32121.5 ,
#         54850.5 ,  42075.  ,  31500.  ,  63905.  ,  28730.  ,  48490.  ,
#         45900.  ,  91905.  ,  49495.5 ,  60600.  ,      0.  ,  30594.05,
#         45000.  ,  87000.  , 118980.  ,  65720.  ,  30255.  ,  30550.  ,
#         43900.  ,  41570.  ,  48195.  ,  70665.  ,  29750.  ,  83580.  ])

# %%
y_pred
# Out:
# array([ 54568.19311111,  30970.83055556,  41752.82833333,  45793.862     ,
#        114384.69388889,  35340.11055556,  40740.14244444,  32899.32277778,
#         53981.05583333,  54244.77916667,  31710.41861111,  49703.2958254 ,
#         40740.14244444,  35481.37858333,  64337.68541667,  49703.2958254 ,
#         46876.27218849,  44188.40566667,  47454.85766667,  26774.37597222,
#         53683.086     ,  70183.81640476,  75005.84722222,  84507.63916667,
#         31991.26805556,  49701.66268651,  33157.75277778,  50232.60833333,
#         36569.53777778,  85376.91166667,  26141.38380556,  56093.01777778,
#         33157.75277778,  80438.4925    ,  23449.93616667,  36446.04      ,
#         49701.66268651,  41801.85      ,  30930.45277778,  70452.07666667,
#         33035.81455159,  52986.1625    ,  54808.26366667,  65081.75472222,
#         49703.2958254 ,  58332.53788889,  23049.73027778,  37438.0465    ,
# ...

# %% [markdown]
# ## Accuracy Metrics for Predicted Prices of Electric Vehicle

# %% [markdown]
# ### Mean Absolute Error:

# %%
#Mean Absolute Error(MAE)
from sklearn.metrics import mean_absolute_error
print("MAE: ",mean_absolute_error(y_test,y_pred))
# Out:
# MAE:  7182.11241316138

# %% [markdown]
# ### Mean Squared Error:

# %%
#Mean Squared Error(MSE)
from sklearn.metrics import mean_squared_error
print("MSE: ",mean_squared_error(y_test,y_pred))
# Out:
# MSE:  107588949.12549096

# %% [markdown]
# ### Root Mean Squared Error:

# %%
#Root Mean Squared Error(RMSE)
print("RMSE: ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE:  10372.509297440565

# %% [markdown]
# ### R Squared (R2):

# %%
#R Squared (R2)
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
print("R2: ",r2)
# Out:
# R2:  0.8165210744785193
